# %% [markdown]
# # Condições aninhadas

# %%
nome = input("Qual é o seu nome: ").title()
if nome == 'Raquel': 
    print(f"Olá! {nome}")
elif nome == 'Pedro' or nome == 'Maria' or nome == 'Paulo':
    print(f"Olá, {nome}! Seu nome é bem popular nom Brasil. ")
elif nome in 'Ana Cláudia Jéssica Juliana':
    print(f"Olá, {nome}! Que belo nome!")
else: 
    print(f"Prazer em te conhecer {nome}!")
# Out:
# Qual é o seu nome:  ester
# Prazer em te conhecer Ester!
