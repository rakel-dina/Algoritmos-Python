# %% [markdown]
# # Operações Aritméticas
#
# **[+] ADIÇÃO**<p>
# **[-] SUBTRAÇÃO**<p>
# **[*] MIULTIPLICAÇÃO**<p>
# **[/] DIVISÃO**<p>
# **[* *] POTÊNCIA**<p>
# **[//] DIVISÃO INTEIRA**<p>
# **[%] RESTO DA DIVISÃO**

# %% [markdown]
# # Ordem de precedência
# 1 - [ ( ) ] <p>
# 2 - [* * ] <p>
# 3 - [ * / // % ] <p>
# 4 - [ + - ] <p>

# %%
5+3*2
# Out:
# 11

# %%
5**2
# Out:
# 25

# %%
5**3
# Out:
# 125

# %%
19//2
# Out:
# 9

# %%
19/2
# Out:
# 9.5

# %%
18%2
# Out:
# 0

# %%
122%3
# Out:
# 2

# %%
4**3
# Out:
# 64

# %%
pow(4,3)
# Out:
# 64

# %%
# raiz quadrada
81**(1/2)
# Out:
# 9.0

# %%
# raiz cubida
127**(1/3)
# Out:
# 5.026525695313479

# %%
nome = input("Qual é seu nome? ")
print(f'Prazer em te conhecer {nome:>20}!') # adiciona 20 espaços à esquerda
# Out:
# Qual é seu nome?  Raquel
# Prazer em te conhecer               Raquel!

# %%
nome = input("Qual é seu nome? ")
print(f'Prazer em te conhecer {nome:^20}!') # Centraliza
# Out:
# Qual é seu nome?  Raquel
# Prazer em te conhecer        Raquel       !

# %%
nome = input("Qual é seu nome? ")
print(f'Prazer em te conhecer {nome:=^20}!')
# Out:
# Qual é seu nome?  Raquel
# Prazer em te conhecer =======Raquel=======!

# %%
n1 = int(input('Digite um valor: '))
n2 = int(input('Digite outro valor: '))
s = n1+n2
m = n1*n2
d = n1/n2
di = n1 // n2
e = n1 ** n2
print(f'soma entre {n1} e {n2} é igual a = {s}')
print(f'multiplicação entre {n1} e {n2} é igual a = {m}')
print(f'dvisão entre {n1} e {n2} é igual a = {d:.3f}') # :.3f é para que fique com  casas decimais
print(f'divisão inteira entre {n1} e {n2} é igual a = {di}', end='') #  [,end='']para não quebrar a linha
print(f' e a potência entre {n1} e {n2} é igual a = {e}')
# Out:
# Digite um valor:  4
# Digite outro valor:  3
# soma entre 4 e 3 é igual a = 7
# multiplicação entre 4 e 3 é igual a = 12
# dvisão entre 4 e 3 é igual a = 1.333
# divisão inteira entre 4 e 3 é igual a = 1 e a potência entre 4 e 3 é igual a = 64
